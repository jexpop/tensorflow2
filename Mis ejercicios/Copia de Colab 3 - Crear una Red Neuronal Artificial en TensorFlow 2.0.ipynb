# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/tensorflow2/blob/master/Colab%203%20-%20Crear%20una%20Red%20Neuronal%20Artificial%20en%20TensorFlow%202.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://storage.googleapis.com/kaggle-datasets-images/2243/3791/9384af51de8baa77f6320901f53bd26b/dataset-cover.png" />
#   Imagen cortesía de: https://www.kaggle.com/
# </p>

# %% [markdown]
# ## Paso 1: Instalar las dependencias y configurar el entorno de GPU

# %%
#!pip install tensorflow-gpu==2.3.0
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# ## Paso 2: Importar las dependencias necesarias para el proyecto

# %%
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
tf.__version__
# Out:
# '2.20.0'

# %% [markdown]
# ## Paso 3: Pre procesado de datos

# %% [markdown]
# ### Cargar el dataset

# %%
#Cargar el dataset Fashion Mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Normalizar las imágenes
#
# Se divide cada imagen en los conjunto de entrenamiento y  de testing entre el valor máximo de cada uno de los píxeles (255).
#
# De este modo, cada píxel se hallará en el rango [0, 1]. Al normalizar las imágenes, nos aseguramos que nuestro modelo de RNA entrenará más rápidamente.

# %%
X_train = X_train / 255.0

# %%
X_test = X_test / 255.0

# %% [markdown]
# ### Redimensionar el dataset
#
# Como vamos a utilizar una red neuronal totalmente conectada, vamos a redimensionar los subconjuntos de entrenamiento y testing a formato de vector en lugar de en formato de matriz.

# %%
#Como cada imagen tiene 28x28 píxeles, usamos la función reshape en todo el dataset de entrenamiento para convertirlo
# en vectores de tamaño [-1 (todos los elementos), anchura * altura]
X_train = X_train.reshape(-1, 28*28)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
#Redimensionamos el conjunto de testing del mismo modo
X_test = X_test.reshape(-1, 28*28)

# %% [markdown]
# ## Paso 4: Construir la Red Neuronal Artificial

# %% [markdown]
# ### Definir el modelo
#
# Simplemente se define un objeto de modelo Sequential.

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ### Añadir la primera capa totalmente conectada (capa Densa)
#
# Hyper-parametros de la capa:
# - número de unidades/neuronas: 128
# - función de activación: ReLU
# - input_shape: (784, )

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784, )))

# %% [markdown]
# otra capa oculta

# %%
model.add(tf.keras.layers.Dense(units=64, activation='relu'))

# %% [markdown]
# ### Añadir una capa de Dropout
#
# Dropout es una técnica de Regularization donde aleatoriamente se asignan a ciertas neuronas de la red el valor cero. De este modo, mientras se entrena, estas neuronas no actualizarán sus valores. Al tener cierto porcentaje de neuronas sin actualizar, el proceso de entrenamiento toma más tiempo pero por contra tenemos menos posibilidades de sufrir overfitting.

# %%
model.add(tf.keras.layers.Dropout(0.2))

# %% [markdown]
# ### Añadir la segunda capa (capa de salida)
#
# - unidades: número de clases (10 en el caso del Fashion MNIST)
# - función de activación: 'softmax' (probabilidades de cada clase)

# %%
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %% [markdown]
# ### Compilar el modelo
#
# - Optimizer: Adam
# - Loss: Sparse softmax (categorical) crossentropy

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Entrenar el modelo

# %%
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.5407 - sparse_categorical_accuracy: 0.8088
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3904 - sparse_categorical_accuracy: 0.8592
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3522 - sparse_categorical_accuracy: 0.8724
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3318 - sparse_categorical_accuracy: 0.8781
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.3129 - sparse_categorical_accuracy: 0.8852
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3015 - sparse_categorical_accuracy: 0.8890
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2872 - sparse_categorical_accuracy: 0.8939
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.8951
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2691 - sparse_categorical_accuracy: 0.8996
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2609 - sparse_categorical_accuracy: 0.9030
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2513 - sparse_categorical_accuracy: 0.9064
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2496 - sparse_categorical_accuracy: 0.9067
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2395 - sparse_categorical_accuracy: 0.9090
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2363 - sparse_categorical_accuracy: 0.9114
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.2300 - sparse_categorical_accuracy: 0.9132
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2241 - sparse_categorical_accuracy: 0.9160
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2212 - sparse_categorical_accuracy: 0.9165
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2145 - sparse_categorical_accuracy: 0.9178
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2135 - sparse_categorical_accuracy: 0.9192
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.2051 - sparse_categorical_accuracy: 0.9227

# %% [markdown]
# ### Evaluación del modelo y predicción

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3515 - sparse_categorical_accuracy: 0.8866

# %%
print("Test accuracy: {}".format(test_accuracy))
# Out:
# Test accuracy: 0.8866000175476074

# %% [markdown]
# ## Paso 5 : Guardar el modelo

# %% [markdown]
# ### Guardar la arquitectura (topoligía) de la red neuronal

# %%
model_json = model.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ### Guardar los pesos de la red neuronal

# %%
model.save_weights("fashion_model.weights.h5")
